# %%
# %matplotlib inline

# %%
import cv2
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
img = cv2.imread('plane.jpg', 0)

# %%
img
# Out:
# array([[161, 161, 162, ..., 178, 177, 177],
#        [160, 160, 161, ..., 177, 177, 177],
#        [163, 162, 162, ..., 177, 177, 177],
#        ...,
#        [176, 173, 172, ..., 190, 190, 189],
#        [175, 174, 174, ..., 188, 188, 186],
#        [173, 175, 176, ..., 189, 188, 187]], dtype=uint8)

# %%
plt.imshow(img)
plt.show()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BAYER_BG2BGR)
plt.imshow(gray)

# %%
sift = cv2.sift(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-6c860c44224a> in <module>()
# ----> 1 sift = cv2.sift(img)
#
# AttributeError: module 'cv2.cv2' has no attribute 'sift'

# %%
cap = cv2.VideoCapture(0)

# %%
import cv2
    2 import numpy as np
    3 
    4 img = cv2.imread('home.jpg')
    5 gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    6 
    7 sift = cv2.xfeatures2d.SIFT_create()
    8 kp = sift.detect(gray,None)
    9 
   10 img=cv2.drawKeypoints(gray,kp)
   11 
   12 cv2.imwrite('sift_keypoints.jpg',img)
# Out:
#   File "<ipython-input-20-294f50187735>", line 2
#     2 import numpy as np
#     ^
# IndentationError: unexpected indent

# %%
cap.release()

# %%
fig, ax = plt.figure()
plt.show()
while( True ):
    ret, frame = cap.read()
    ax.imshow(frame)
    ax.set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-ff5b4c84ec8a> in <module>()
# ----> 1 fig, ax = plt.figure()
#       2 plt.show()
#       3 while( True ):
#       4     ret, frame = cap.read()
#       5     ax.imshow(frame)
#
# TypeError: 'Figure' object is not iterable

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

ret, frame = cap.read()
ax1.imshow(frame)
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)
plt.imshow(img)
plt.show()

ax1.update(img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-132-aec81c1396f7> in <module>()
#       4 plt.show()
#       5
# ----> 6 ax1.update(img)
#
# /Users/sadegh/anaconda3/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     883         try:
#     884             ret = [_update_property(self, k, v)
# --> 885                    for k, v in props.items()]
#     886         finally:
#     887             self.eventson = store
#
# AttributeError: 'numpy.ndarray' object has no attribute 'items'

# %%
"""
A simple example of an animated plot
"""
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

fig, ax = plt.subplots()

x = np.arange(0, 2*np.pi, 0.01)
line, = ax.plot(x, np.sin(x))


def animate(i):
    line.set_ydata(np.sin(x + i/10.0))  # update the data
    return line,


# Init only required for blitting to give a clean slate.
def init():
    line.set_ydata(np.ma.array(x, mask=True))
    return line,

ani = animation.FuncAnimation(fig, animate, np.arange(1, 200), init_func=init,
                              interval=25, blit=True)
plt.show()

# %%
img = cv2.ellipse(img,(256,256),(100,50),0,0,180,255,-1)

# %%
plt.imshow(img)
plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img1 = cv2.imread('plane.jpg',0)          # queryImage
img2 = cv2.imread('plane.jpg',0) # trainImage

# Initiate SIFT detector
orb = cv2.ORB_create()

# find the keypoints and descriptors with SIFT
kp1, des1 = orb.detectAndCompute(img1,None)
kp2, des2 = orb.detectAndCompute(img2,None)

# %%
# create BFMatcher object
bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)

img4 = None

# Match descriptors.
matches = bf.match(des1,des2)

# Sort them in the order of their distance.
matches = sorted(matches, key = lambda x:x.distance)

# Draw first 10 matches.
img3 = cv2.drawMatches(img1,kp1,img2,kp2,matches[:100], flags=2, outImg=img4)

plt.imshow(img3),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x11508d4e0>, None)
